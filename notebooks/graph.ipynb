# %%
import os

if os.getcwd().endswith("notebooks"):
    os.chdir("..")

print(os.getcwd())
# Out:
# /Users/cmcoutosilva/Projects/github/labrag

# %%
from labrag.agents.graph import create_graph
from labrag.ingestion.loaders.vector_store import VectorStore

vector_store = VectorStore()

graph = create_graph(vector_store)
graph.compile()
# Out:
# 2025-06-29 10:32:59.634 | INFO     | labrag.ingestion.loaders.vector_store:load:130 - Loaded existing vector store from data/vector_store
